# %% [markdown]
# **ETG - BAKERY INVENTORY MANAGEMENT SYSTEM**

# %% [markdown]
# **AVAIABLE PRODUCTS IN THE INVERTORY OF BAKERY**

# %%
record_dict = {101:{"product_name" : "limca","product_category" : "cool drinks","product_quantity" : 10, "product_price" : 20,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              102:{"product_name" : "coco-cola","product_category" : "cool drinks","product_quantity" : 20, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              103:{"product_name" : "fanta","product_category" : "cool drinks","product_quantity" : 30, "product_price" : 25,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              104:{"product_name" : "sprite","product_category" : "cool drinks","product_quantity" : 25, "product_price" : 15,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              105:{"product_name" : "maaza","product_category" : "cool drinks","product_quantity" : 20, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              106:{"product_name" : "slice","product_category" : "cool drinks","product_quantity" : 40, "product_price" : 30,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              107:{"product_name" : "pepsi","product_category" : "cool drinks","product_quantity" : 35, "product_price" : 15,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              108:{"product_name" : "snickers","product_category" : "chocolates","product_quantity" : 50, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              109:{"product_name" : "dairy milk","product_category" : "chocolates","product_quantity" : 100, "product_price" : 20,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              110:{"product_name" : "5 star","product_category" : "chocolates","product_quantity" : 150, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              111:{"product_name" : "milkybar","product_category" : "chocolates","product_quantity" : 50, "product_price" : 20,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              112:{"product_name" : "perk","product_category" : "chocolates","product_quantity" : 100, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              113:{"product_name" : "munch","product_category" : "chocolates","product_quantity" : 250, "product_price" : 5,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              114:{"product_name" : "cadbury shorts","product_category" : "chocolates","product_quantity" : 500, "product_price" : 2,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              115:{"product_name" : "cadbury gems","product_category" : "chocolates","product_quantity" : 300, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              116:{"product_name" : "kit-kat","product_category" : "chocolates","product_quantity" : 250, "product_price" : 20,"purchase_year_of_product": 2021, "expire_year_of_product" : 2024},
              117:{"product_name" : "white bread","product_category" : "bread","product_quantity" : 50, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              118:{"product_name" : "wheat bread","product_category" : "bread","product_quantity" : 150, "product_price" : 20,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              119:{"product_name" : "whole grain bread","product_category" : "bread","product_quantity" : 250, "product_price" : 30,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              120:{"product_name" : "rye bread","product_category" : "bread","product_quantity" : 100, "product_price" : 15,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              121:{"product_name" : "pretzel","product_category" : "bread","product_quantity" : 50, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              122:{"product_name" : "swiss roll","product_category" : "bread","product_quantity" : 350, "product_price" : 20,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              123:{"product_name" : "craissant","product_category" : "bread","product_quantity" : 250, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              124:{"product_name" : "hamburger bun","product_category" : "bread","product_quantity" : 50, "product_price" : 250,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              125:{"product_name" : "hot dog bun","product_category" : "bread","product_quantity" : 50, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              126:{"product_name" : "donut","product_category" : "bread","product_quantity" : 150, "product_price" : 15,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              127:{"product_name" : "rolls","product_category" : "bread","product_quantity" : 100, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              128:{"product_name" : "breadsticks","product_category" : "bread","product_quantity" : 350, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              129:{"product_name" : "french bread","product_category" : "bread","product_quantity" : 100, "product_price" : 20,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              130:{"product_name" : "angel cake","product_category" : "cake","product_quantity" : 150, "product_price" : 100,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              131:{"product_name" : "apple cake","product_category" : "cake","product_quantity" : 100, "product_price" : 150,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              132:{"product_name" : "babka","product_category" : "cake","product_quantity" : 50, "product_price" : 100,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              133:{"product_name" : "banana cake","product_category" : "cake","product_quantity" : 25, "product_price" : 200,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              134:{"product_name" : "batik cake","product_category" : "cake","product_quantity" : 120, "product_price" : 150,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              135:{"product_name" : "battenberg cake","product_category" : "cake","product_quantity" : 20, "product_price" : 270,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              136:{"product_name" : "blackout cake","product_category" : "cake","product_quantity" : 150, "product_price" : 200,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              137:{"product_name" : "brownie","product_category" : "cake","product_quantity" : 250, "product_price" : 50,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              138:{"product_name" : "cheese cake","product_category" : "cake","product_quantity" : 150, "product_price" : 100,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              139:{"product_name" : "butter cake","product_category" : "cake","product_quantity" : 50, "product_price" : 200,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              140:{"product_name" : "carrot cake","product_category" : "cake","product_quantity" : 150, "product_price" : 70,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              141:{"product_name" : "cupcake","product_category" : "cake","product_quantity" : 350, "product_price" : 10,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022},
              142:{"product_name" : "coconut cake","product_category" : "cake","product_quantity" : 50, "product_price" : 300,"purchase_year_of_product": 2021, "expire_year_of_product" : 2022}}

# %%
record_dict
# Out:
# {101: {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'limca',
#   'product_price': 20,
#   'product_quantity': 10,
#   'purchase_year_of_product': 2021},
#  102: {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'coco-cola',
#   'product_price': 10,
#   'product_quantity': 20,
#   'purchase_year_of_product': 2021},
#  103: {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'fanta',
#   'product_price': 25,
#   'product_quantity': 30,
#   'purchase_year_of_product': 2021},
#  104: {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'sprite',
#   'product_price': 15,
#   'product_quantity': 25,
#   'purchase_year_of_product': 2021},
#  105: {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'maaza',
#   'product_price': 10,
#   'product_quantity': 20,
# ...

# %% [markdown]
# **STORING THE AVAIABLE PRODUCTS INTO record.json FILE USING JSON PACKAGE**

# %%
import json
record=json.dumps(record_dict)

# %%
record
# Out:
# '{"101": {"product_name": "limca", "product_category": "cool drinks", "product_quantity": 10, "product_price": 20, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "102": {"product_name": "coco-cola", "product_category": "cool drinks", "product_quantity": 20, "product_price": 10, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "103": {"product_name": "fanta", "product_category": "cool drinks", "product_quantity": 30, "product_price": 25, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "104": {"product_name": "sprite", "product_category": "cool drinks", "product_quantity": 25, "product_price": 15, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "105": {"product_name": "maaza", "product_category": "cool drinks", "product_quantity": 20, "product_price": 10, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "106": {"product_name": "slice", "product_category": "cool drinks", "product_quantity": 40,
# ...

# %%
record_file=open("record.json","w")
record_file.write(record)
record_file.close()

# %% [markdown]
# **LOADING THE PRODUCTS FROM THE record.json FILE TO record_dict USING JSON PACKAGE FOR PURCHASING NEW PRODUCTS OR UPDATING THE EXISTING PRODUCTS**

# %%
import json
record_file=open("record.json","r")
record_dict=json.loads(record)
record_dict
# Out:
# {'101': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'limca',
#   'product_price': 20,
#   'product_quantity': 10,
#   'purchase_year_of_product': 2021},
#  '102': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'coco-cola',
#   'product_price': 10,
#   'product_quantity': 20,
#   'purchase_year_of_product': 2021},
#  '103': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'fanta',
#   'product_price': 25,
#   'product_quantity': 30,
#   'purchase_year_of_product': 2021},
#  '104': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'sprite',
#   'product_price': 15,
#   'product_quantity': 25,
#   'purchase_year_of_product': 2021},
#  '105': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'maaza',
#   'product_price': 10,
#   'product_quantity': 20,
# ...

# %% [markdown]
# **ADDING/PURCHASING THE REQUIRED PRODUCTS FOR THE BAKERY INVENTORY**

# %%
print("-----------------------------------------------------------")
no_of_products = int(input("ENTER THE NUMBER OF PRODUCTS THAT YOU WANT TO ADD/PURCHASE : "))

for j in range(no_of_products):
  print("-----------------------------------------------------------")
  print("ENTER THE DETAILS OF PRODUCT ",j+1)
  print("-----------------------------------------------------------")
  product_id = input("ENTER THE PRODUCT ID : ")
  if product_id not in record_dict.keys():
    print("-----------------------------------------------------------")
    print("PRODUCT DOES NOT EXIST.....") 
    print("-----------------------------------------------------------")
    product_name = input("ENTER THE NAME OF THE PRODUCT : ")
    product_category = input("ENTER THE CATEGORY OF THE PRODUCT : ")
    product_quantity = int(input("ENTER THE QUANTITY OF THE PRODUCT THAT YOU WANT TO PURCHASE : "))
    product_price = int(input("ENTER THE PRICE OF THE PRODUCT : "))
    purchase_year_of_product = int(input("ENTER THE PURCHASE YEAR OF PRODUCT : "))
    expire_year_of_product = int(input("ENTER THE EXPIRE YEAR OF PRODUCT : "))
    record_dict[product_id] ={"product_name" : product_name,"product_category" : product_category,"product_quantity" : product_quantity, "product_price" : product_price,"purchase_year_of_product": purchase_year_of_product, "expire_year_of_product" : expire_year_of_product}
  else:
    print("-----------------------------------------------------------")
    print("PRODUCT ALREADY EXIST.....")
    print("-----------------------------------------------------------")
    print("NAME OF THE PRODUCT : ",record_dict[product_id]["product_name"])
    print("CATEGORY OF THE PRODUCT : ",record_dict[product_id]["product_category"])
    print("PRICE OF THE PRODUCT : ",record_dict[product_id]["product_price"])
    print("PURCHASE YEAR OF PRODUCT : ",record_dict[product_id]["purchase_year_of_product"])
    print("EXPIRE YEAR OF PRODUCT : ",record_dict[product_id]["expire_year_of_product"])
    product_quan = int(input("ENTER THE QUANTITY OF THE PRODUCT THAT YOU WANT TO ADD : "))
    record_dict[product_id]["product_quantity"]=record_dict[product_id]["product_quantity"] + product_quan
   
    
print("-----------------------------------------------------------")
print("PURCHASING COMPLETED...")
print("-----------------------------------------------------------")
# Out:
# -----------------------------------------------------------
# ENTER THE NUMBER OF PRODUCTS THAT YOU WANT TO ADD/PURCHASE : 7
# -----------------------------------------------------------
# ENTER THE DETAILS OF PRODUCT  1
# -----------------------------------------------------------
# ENTER THE PRODUCT ID : 142
# -----------------------------------------------------------
# PRODUCT ALREADY EXIST.....
# -----------------------------------------------------------
# NAME OF THE PRODUCT :  coconut cake
# CATEGORY OF THE PRODUCT :  cake
# PRICE OF THE PRODUCT :  300
# PURCHASE YEAR OF PRODUCT :  2021
# EXPIRE YEAR OF PRODUCT :  2022
# ENTER THE QUANTITY OF THE PRODUCT THAT YOU WANT TO ADD : 23
# -----------------------------------------------------------
# ENTER THE DETAILS OF PRODUCT  2
# -----------------------------------------------------------
# ENTER THE PRODUCT ID : 101
# -----------------------------------------------------------
# PRODUCT ALREADY EXIST.....
# ...

# %%
record_dict
# Out:
# {'101': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'limca',
#   'product_price': 20,
#   'product_quantity': 47,
#   'purchase_year_of_product': 2021},
#  '102': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'coco-cola',
#   'product_price': 10,
#   'product_quantity': 20,
#   'purchase_year_of_product': 2021},
#  '103': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'fanta',
#   'product_price': 25,
#   'product_quantity': 30,
#   'purchase_year_of_product': 2021},
#  '104': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'sprite',
#   'product_price': 15,
#   'product_quantity': 25,
#   'purchase_year_of_product': 2021},
#  '105': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'maaza',
#   'product_price': 10,
#   'product_quantity': 20,
# ...

# %% [markdown]
# **UPDATING THE record.json FILE WITH THE ADDED/PURCHASED PRODUCTS USING JSON PACKAGES**

# %%
import json
record=json.dumps(record_dict)

# %%
record
# Out:
# '{"101": {"product_name": "limca", "product_category": "cool drinks", "product_quantity": 47, "product_price": 20, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "102": {"product_name": "coco-cola", "product_category": "cool drinks", "product_quantity": 20, "product_price": 10, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "103": {"product_name": "fanta", "product_category": "cool drinks", "product_quantity": 30, "product_price": 25, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "104": {"product_name": "sprite", "product_category": "cool drinks", "product_quantity": 25, "product_price": 15, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "105": {"product_name": "maaza", "product_category": "cool drinks", "product_quantity": 20, "product_price": 10, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "106": {"product_name": "slice", "product_category": "cool drinks", "product_quantity": 40,
# ...

# %%
record_file=open("record.json","w")
record_file.write(record)
record_file.close()

# %% [markdown]
# **LOADING THE PRODUCTS FROM THE record.json FILE TO record_dictionary USING JSON PACKAGE FOR SELLING THOSE PRODUCTS**

# %%
import json
record_file=open("record.json","r")
record_dictionary=json.loads(record)
record_file.close()

# %%
record_dictionary
# Out:
# {'101': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'limca',
#   'product_price': 20,
#   'product_quantity': 47,
#   'purchase_year_of_product': 2021},
#  '102': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'coco-cola',
#   'product_price': 10,
#   'product_quantity': 20,
#   'purchase_year_of_product': 2021},
#  '103': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'fanta',
#   'product_price': 25,
#   'product_quantity': 30,
#   'purchase_year_of_product': 2021},
#  '104': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'sprite',
#   'product_price': 15,
#   'product_quantity': 25,
#   'purchase_year_of_product': 2021},
#  '105': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'maaza',
#   'product_price': 10,
#   'product_quantity': 20,
# ...

# %% [markdown]
# **SELLING OF PRODUCTS FROM THE BAKERY INVENTORY AND PRINTING BILLS TO THE CUSTOMERS**

# %%
import time
lst=[]
 
print("---------------------------------------------------------")
print("ETG - BAKERY INVENTORY MANAGEMENT SYSTEM")
print("BY KARKAVELRAJA J")
print("---------------------------------------------------------")
print(time.ctime())
print("---------------------------------------------------------")
 
user_input=int(input("ENTER THE NUMBER OF PRODUCTS : "))
print("---------------------------------------------------------")
for i in range(user_input) :
  print("DETAILS OF PRODUCT ",i+1)
  print("---------------------------------------------------------")
  product_id=input("ENTER THE PRODUCT ID : ")
  product_quan=int(input("ENTER THE QUANTITY OF PRODUCT : "))
 
  
  if product_id in record_dictionary.keys() :
    print("ID OF THE PRODUCT       : ",product_id)
    print("NAME OF THE PRODUCT     : ",record_dictionary[product_id]["product_name"])
    print("CATEGORY OF THE PRODUCT : ",record_dictionary[product_id]["product_category"])
    print("PRICE OF THE PRODUCT    : ",record_dictionary[product_id]["product_price"])
    print("QUANTITY OF THE PRODUCT : ",product_quan)
    record_dictionary[product_id]["product_quantity"]=record_dictionary[product_id]["product_quantity"] - (product_quan)
    amount=record_dictionary[product_id]["product_price"]*product_quan
    print("---------------------------------------------------------")
    print("AMOUNT OF THE PRODUCT   : ",amount)
    print("---------------------------------------------------------")
    lst.append(amount)
 
  else:
    print("---------------------------------------------------------")
    print("INVALID PRODUCT ID")
    print("---------------------------------------------------------")
 
print("---------------------------------------------------------")
print("TOTAL PRICE OF THE PRODUCT: ",sum(lst))
print("---------------------------------------------------------")
 
print("************THANK**YOU***********VISIT**AGAIN************")
print("---------------------------------------------------------")
# Out:
# ---------------------------------------------------------
# ETG - BAKERY INVENTORY MANAGEMENT SYSTEM
# BY KARKAVELRAJA J
# ---------------------------------------------------------
# Sat Sep  4 11:18:33 2021
# ---------------------------------------------------------
# ENTER THE NUMBER OF PRODUCTS : 5
# ---------------------------------------------------------
# DETAILS OF PRODUCT  1
# ---------------------------------------------------------
# ENTER THE PRODUCT ID : 110
# ENTER THE QUANTITY OF PRODUCT : 10
# ID OF THE PRODUCT       :  110
# NAME OF THE PRODUCT     :  5 star
# CATEGORY OF THE PRODUCT :  chocolates
# PRICE OF THE PRODUCT    :  10
# QUANTITY OF THE PRODUCT :  10
# ---------------------------------------------------------
# AMOUNT OF THE PRODUCT   :  100
# ---------------------------------------------------------
# DETAILS OF PRODUCT  2
# ---------------------------------------------------------
# ENTER THE PRODUCT ID : 120
# ENTER THE QUANTITY OF PRODUCT : 15
# ...

# %%
sales_dict=record_dictionary
sales_dict
# Out:
# {'101': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'limca',
#   'product_price': 20,
#   'product_quantity': 47,
#   'purchase_year_of_product': 2021},
#  '102': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'coco-cola',
#   'product_price': 10,
#   'product_quantity': 20,
#   'purchase_year_of_product': 2021},
#  '103': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'fanta',
#   'product_price': 25,
#   'product_quantity': 30,
#   'purchase_year_of_product': 2021},
#  '104': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'sprite',
#   'product_price': 15,
#   'product_quantity': 25,
#   'purchase_year_of_product': 2021},
#  '105': {'expire_year_of_product': 2022,
#   'product_category': 'cool drinks',
#   'product_name': 'maaza',
#   'product_price': 10,
#   'product_quantity': 20,
# ...

# %% [markdown]
# **CHANGES TO THE QUANTITY OF PRODUCTS ARE UPDATED ONTO THE sales.json FILE USING JSON PACKAGES**

# %%
import json
sales=json.dumps(sales_dict)

# %%
sales
# Out:
# '{"101": {"product_name": "limca", "product_category": "cool drinks", "product_quantity": 47, "product_price": 20, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "102": {"product_name": "coco-cola", "product_category": "cool drinks", "product_quantity": 20, "product_price": 10, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "103": {"product_name": "fanta", "product_category": "cool drinks", "product_quantity": 30, "product_price": 25, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "104": {"product_name": "sprite", "product_category": "cool drinks", "product_quantity": 25, "product_price": 15, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "105": {"product_name": "maaza", "product_category": "cool drinks", "product_quantity": 20, "product_price": 10, "purchase_year_of_product": 2021, "expire_year_of_product": 2022}, "106": {"product_name": "slice", "product_category": "cool drinks", "product_quantity": 40,
# ...

# %%
sales_info=open("sales.json","w")
sales_info.write(sales)
sales_info.close()
